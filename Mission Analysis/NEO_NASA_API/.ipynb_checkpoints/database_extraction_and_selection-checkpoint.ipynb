# %%
from astroquery.jplhorizons import Horizons
from astroquery.jplsbdb import SBDB
from astropy.table import QTable
import astropy.units as u

#import pandas as pd
import numpy as np
import requests
from pprint import pprint
from array import *

# %% [markdown]
# # Call to JPL SBDB

# %%
def get_dict(name_list):
    # Return information for each bodies in name_list from JPL Small Body Database in form of dictionair
    # INPUT
    # name_list      list [name1, name2, ..., nameN]
    # OUTPUT
    # dict_bodies    dict with the following structure
    # str(name): "fullname"
    #         "our_id"                is the id inside the new dict, from 0 to N-1 where N is the name_list length
    #         "neo_flag"
    #         "orbit_class"
    #         "pha_flag"
    #         "object_kind"
    #         "moid"
    #         "condition_code"
    #         "rms"
    #         "orbit_comment"
    #         "magn_radius_flag"      is "H" if the next parameter is the magnitude, is "D" if the next parameter is the diameter
    #         "H" or "D"
    #         "spectral_category_flag"     T, S or 0
    #         "spectral_category"
    #         "impacts": str(impact id):   'width'  
    #                                      'energy'
    #                                      'stretch'
    #                                      'ip'
    #                                      'dt'
    #                                      'date'
    #                                      'sigma_lov'
    #                                      'h'
    #                                      'mass'
    #                                      'v_inf'
    #                                      'sigma_imp'
    #                                      'method'
    #                                      'ts'
    #                                      'diam'
    #                                      'dist'
    #                                      'v_imp'
    #                                      'ps'
    
    our_id=0;
    dict_bodies={};

    for name in name_list:
        sbdb = SBDB.query(name, neo_only=True, full_precision=True, phys=True, virtual_impactor=True)
        asteroid={"fullname": sbdb["object"]["fullname"],# TODO vogliamo fare un check?
          "our_id":our_id,
          "neo_flag": sbdb["object"]["neo"],
          "orbit_class":sbdb["object"]["orbit_class"]["code"],
          "pha_flag":sbdb["object"]["pha"],
          "object_kind":sbdb["object"]["kind"], #an asteroid numbered au unbered asteroid (cn, cu for comet)
          "moid": sbdb["orbit"]["moid"],
          "condition_code": sbdb["orbit"]["condition_code"], #OCC
          "rms": sbdb["orbit"]["rms"],
          "orbit_comment":sbdb["orbit"]["comment"],
         };
        try:     
            asteroid["magn_radius_flag"]='H';
            asteroid["H"]=sbdb['phys_par']['H'];
        except:
            asteroid["magn_radius_flag"]='D';
            asteroid["D"]=sbdb['phys_par']['diameter'];
        asteroid["impacts"]={}
        flag_bool=1;
        if 'phys_par' in sbdb.keys():
            spect_flag=0;
            if 'spec_T' in sbdb['phys_par'].keys():
                asteroid["spectral_category_flag"]='T'
                asteroid["spectral_category"]=sbdb['phys_par']['spec_T']
                spect_flag=1;
            if 'spec_B' in sbdb['phys_par'].keys():
                asteroid["spectral_category_flag"]='B'
                asteroid["spectral_category"]=sbdb['phys_par']['spec_B']
                spect_flag=1;
            if spect_flag==0:
                asteroid["spectral_category_flag"]='0'
        else:
            asteroid["spectral_category"]='0'
                
        if 'ip' in sbdb["vi_data"]:
            n_imp=len(sbdb["vi_data"]['ip']);
            for key in sbdb["vi_data"].keys():
                if flag_bool==1:
                    for i in range(0,n_imp):
                        asteroid["impacts"][str(i)]={};
                    flag_bool=0;
                for i in range(0,n_imp): 
                    try:
                        asteroid["impacts"][str(i)][key]=sbdb["vi_data"][key][i];
                    except:
                        pprint(name+" could raise error in importing virtual impact data") #this exception is raised if only one impact is present
        dict_bodies[name]=asteroid;
        our_id=our_id+1;
        flag_bool=1;
        del asteroid;
    return dict_bodies

# %% [markdown]
# # Extract ESA risk list

# %%
def extract_esa_name_from_file(file_name):
    f = open(file_name, "r")
    line=f.readline()
    line=f.readline()
    line=f.readline()
    line=f.readline()
    counter=0;
    esa_names=[]
    for line in f:
        word="";
        for c in line:
            if c==' ':
                break;
            else:
                word=word+c;
        esa_names.append(word);  
    return esa_names

# %%
esa_risk_names=extract_esa_name_from_file("esa_risk_list.txt");

# %% [markdown]
# # Extract SENTRY risk list

# %%
def get_sentry_risk_list():
    url = 'https://ssd-api.jpl.nasa.gov/sentry.api'
    r = requests.get(url)
    data = r.json()
    sentry_risk_names=[];
    for i in range(0,len(data['data'])):
        name_=""
        name=data['data'][i]['des'];
        for c in name:
            if c==' ':
                a=0;
            else:
                name_=name_+c;
        sentry_risk_names.append(name_)
    return sentry_risk_names

# %%
sentry_risk_names=get_sentry_risk_list()

# %% [markdown]
# # Merge risk lists

# %%
risk_list=esa_risk_names;
counter=0;
for risk_name in sentry_risk_names:
    if risk_name not in esa_risk_names:
        risk_list.append(risk_name)

# %% [markdown]
# # Query SBDB for all risk list elements

# %%
dict_risk_list=get_dict(risk_list);
# Out:
# '29075 could raise error in importing virtual impact data'
# ciao

# %% [markdown]
# # select only asteroids with info on spectral type

# %%
for key in dict_risk_list.keys():
    if dict_risk_list[key]['spectral_category_flag']=="B":
        pprint(key)
# Out:
# '101955'

# %%
dict_risk_list['101955']
# Out:
# {'fullname': '101955 Bennu (1999 RQ36)',
#  'our_id': 1201,
#  'neo_flag': True,
#  'orbit_class': 'APO',
#  'pha_flag': True,
#  'object_kind': 'an',
#  'moid': Unit("0.0032228 AU"),
#  'condition_code': '0',
#  'rms': '.27502',
#  'orbit_comment': 'Nongravitational accels. using nonstandard g(r) = (1 au/ r)^2.25',
#  'magn_radius_flag': 'H',
#  'H': '20.19',
#  'impacts': {'0': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 14900.0,
#    'ip': 4.1e-05,
#    'dt': <Quantity 154.49 yr>,
#    'date': '2175-09-25.15',
#    'sigma_lov': 1.344,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.234,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -2.6},
#   '1': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 118000.0,
#    'ip': 6.4e-06,
#    'dt': <Quantity 154.49 yr>,
#    'date': '2175-09-25.16',
#    'sigma_lov': 1.051,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.453,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -3.41},
#   '2': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 25600.0,
#    'ip': 3.1e-06,
#    'dt': <Quantity 155.49 yr>,
#    'date': '2176-09-24.39',
#    'sigma_lov': 2.458,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.174,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -3.73},
#   '3': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 96700.0,
#    'ip': 1.1e-05,
#    'dt': <Quantity 159.49 yr>,
#    'date': '2180-09-24.36',
#    'sigma_lov': 0.894,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.191,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -3.17},
#   '4': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 83300.0,
#    'ip': 2e-05,
#    'dt': <Quantity 159.49 yr>,
#    'date': '2180-09-24.39',
#    'sigma_lov': 0.529,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.115,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -2.94},
#   '5': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1550000.0,
#    'ip': 9.4e-08,
#    'dt': <Quantity 160.49 yr>,
#    'date': '2181-09-24.51',
#    'sigma_lov': 2.213,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.007,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.26},
#   '6': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 461000.0,
#    'ip': 1.4e-06,
#    'dt': <Quantity 160.49 yr>,
#    'date': '2181-09-24.54',
#    'sigma_lov': 1.361,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.173,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.1},
#   '7': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 415000.0,
#    'ip': 6.3e-07,
#    'dt': <Quantity 160.49 yr>,
#    'date': '2181-09-24.55',
#    'sigma_lov': 1.882,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.223,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.44},
#   '8': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 393000.0,
#    'ip': 9.1e-09,
#    'dt': <Quantity 160.49 yr>,
#    'date': '2181-09-24.58',
#    'sigma_lov': 3.408,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.568,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -6.28},
#   '9': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 352000.0,
#    'ip': 2.9e-06,
#    'dt': <Quantity 160.49 yr>,
#    'date': '2181-09-24.78',
#    'sigma_lov': 1.021,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.007,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -3.78},
#   '10': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 30300.0,
#    'ip': 3.5e-06,
#    'dt': <Quantity 161.49 yr>,
#    'date': '2182-09-24.85',
#    'sigma_lov': -2.291,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.281,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -3.69},
#   '11': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 38700.0,
#    'ip': 1.1e-08,
#    'dt': <Quantity 161.49 yr>,
#    'date': '2182-09-24.85',
#    'sigma_lov': -4.053,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.195,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.21},
#   '12': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 26100.0,
#    'ip': 1.4e-06,
#    'dt': <Quantity 161.49 yr>,
#    'date': '2182-09-24.86',
#    'sigma_lov': -2.753,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.074,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.09},
#   '13': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 69000.0,
#    'ip': 2.4e-10,
#    'dt': <Quantity 163.49 yr>,
#    'date': '2184-09-24.27',
#    'sigma_lov': 4.75,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.429,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -7.85},
#   '14': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 7070.0,
#    'ip': 6.5e-09,
#    'dt': <Quantity 163.49 yr>,
#    'date': '2184-09-24.36',
#    'sigma_lov': 4.585,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.019,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -6.43},
#   '15': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 965000.0,
#    'ip': 2.8e-09,
#    'dt': <Quantity 164.49 yr>,
#    'date': '2185-09-24.50',
#    'sigma_lov': 3.576,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.082,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.79},
#   '16': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 194000.0,
#    'ip': 1.4e-08,
#    'dt': <Quantity 164.49 yr>,
#    'date': '2185-09-24.51',
#    'sigma_lov': 3.561,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.226,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.1},
#   '17': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 397000.0,
#    'ip': 6.4e-09,
#    'dt': <Quantity 164.49 yr>,
#    'date': '2185-09-24.52',
#    'sigma_lov': 3.556,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.361,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.44},
#   '18': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 25500.0,
#    'ip': 6.3e-05,
#    'dt': <Quantity 164.49 yr>,
#    'date': '2185-09-24.59',
#    'sigma_lov': 0.182,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.038,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -2.44},
#   '19': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 83400.0,
#    'ip': 2e-05,
#    'dt': <Quantity 164.49 yr>,
#    'date': '2185-09-24.59',
#    'sigma_lov': -0.111,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.073,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -2.95},
#   '20': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 1420000.0,
#    'ip': 9.4e-07,
#    'dt': <Quantity 165.49 yr>,
#    'date': '2186-09-24.74',
#    'sigma_lov': 0.692,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.003,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.28},
#   '21': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 805000.0,
#    'ip': 1.5e-06,
#    'dt': <Quantity 165.49 yr>,
#    'date': '2186-09-24.97',
#    'sigma_lov': -0.187,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.543,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.08},
#   '22': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 751000.0,
#    'ip': 8.1e-07,
#    'dt': <Quantity 165.49 yr>,
#    'date': '2186-09-25.00',
#    'sigma_lov': 1.327,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.295,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.34},
#   '23': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 752000.0,
#    'ip': 4.9e-08,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-24.94',
#    'sigma_lov': -2.744,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.132,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.56},
#   '24': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1040000.0,
#    'ip': 1.2e-07,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-24.96',
#    'sigma_lov': -2.284,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.028,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.17},
#   '25': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1150000.0,
#    'ip': 3.4e-10,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-24.97',
#    'sigma_lov': -4.06,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.26,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -7.71},
#   '26': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 273000.0,
#    'ip': 5.3e-07,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-25.06',
#    'sigma_lov': -2.223,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.002,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.53},
#   '27': {'width': 0.0,
#    'energy': 1153.0,
#    'stretch': 434000.0,
#    'ip': 2e-10,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-25.07',
#    'sigma_lov': -4.433,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6.01 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.114,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -7.95},
#   '28': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 19800.0,
#    'ip': 8.3e-06,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-25.14',
#    'sigma_lov': 1.689,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.863,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -3.33},
#   '29': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 484000.0,
#    'ip': 2.4e-07,
#    'dt': <Quantity 166.49 yr>,
#    'date': '2187-09-25.21',
#    'sigma_lov': 2.199,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.451,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.87},
#   '30': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 64600.0,
#    'ip': 1.6e-08,
#    'dt': <Quantity 167.49 yr>,
#    'date': '2188-09-24.24',
#    'sigma_lov': 3.283,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.985,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.05},
#   '31': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 15800.0,
#    'ip': 8e-07,
#    'dt': <Quantity 167.49 yr>,
#    'date': '2188-09-24.35',
#    'sigma_lov': 2.781,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.896,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.35},
#   '32': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 2900000.0,
#    'ip': 1.1e-09,
#    'dt': <Quantity 168.49 yr>,
#    'date': '2189-09-25.18',
#    'sigma_lov': 3.504,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.295,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -7.22},
#   '33': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 31900.0,
#    'ip': 4.9e-08,
#    'dt': <Quantity 169.49 yr>,
#    'date': '2190-09-24.79',
#    'sigma_lov': 3.737,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.08,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -5.57},
#   '34': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1620000.0,
#    'ip': 1.2e-06,
#    'dt': <Quantity 169.49 yr>,
#    'date': '2190-09-24.81',
#    'sigma_lov': 0.311,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.014,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.16},
#   '35': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1450000.0,
#    'ip': 6.7e-07,
#    'dt': <Quantity 169.49 yr>,
#    'date': '2190-09-24.81',
#    'sigma_lov': 0.957,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.198,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.43},
#   '36': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 12300.0,
#    'ip': 5e-09,
#    'dt': <Quantity 169.49 yr>,
#    'date': '2190-09-24.83',
#    'sigma_lov': 4.393,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.735,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -6.56},
#   '37': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1610000.0,
#    'ip': 3.5e-07,
#    'dt': <Quantity 169.49 yr>,
#    'date': '2190-09-25.46',
#    'sigma_lov': -1.393,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.271,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.71},
#   '38': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 305000.0,
#    'ip': 5.4e-06,
#    'dt': <Quantity 170.49 yr>,
#    'date': '2191-09-25.13',
#    'sigma_lov': -0.164,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.027,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -3.53},
#   '39': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 737000.0,
#    'ip': 1.4e-06,
#    'dt': <Quantity 170.49 yr>,
#    'date': '2191-09-25.18',
#    'sigma_lov': -0.146,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.661,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.11},
#   '40': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 1200000.0,
#    'ip': 1.3e-06,
#    'dt': <Quantity 170.49 yr>,
#    'date': '2191-09-25.32',
#    'sigma_lov': -0.172,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.166,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.15},
#   '41': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 1390000.0,
#    'ip': 1e-06,
#    'dt': <Quantity 170.49 yr>,
#    'date': '2191-09-25.38',
#    'sigma_lov': 0.535,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.032,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.24},
#   '42': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 1140000.0,
#    'ip': 5.6e-07,
#    'dt': <Quantity 170.49 yr>,
#    'date': '2191-09-25.55',
#    'sigma_lov': 0.899,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.728,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.51},
#   '43': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 53200.0,
#    'ip': 5.8e-07,
#    'dt': <Quantity 171.49 yr>,
#    'date': '2192-09-24.17',
#    'sigma_lov': -2.547,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.172,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.5},
#   '44': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 768000.0,
#    'ip': 1e-10,
#    'dt': <Quantity 171.49 yr>,
#    'date': '2192-09-24.17',
#    'sigma_lov': -4.443,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.207,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -8.25},
#   '45': {'width': 0.0,
#    'energy': 1154.0,
#    'stretch': 374000.0,
#    'ip': 8.4e-07,
#    'dt': <Quantity 171.49 yr>,
#    'date': '2192-09-24.19',
#    'sigma_lov': -0.213,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6.02 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.083,
#    'v_imp': <Quantity 12.7 km / s>,
#    'ps': -4.34},
#   '46': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 444000.0,
#    'ip': 3.3e-07,
#    'dt': <Quantity 171.49 yr>,
#    'date': '2192-09-24.41',
#    'sigma_lov': -2.209,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.01,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.74},
#   '47': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 1930000.0,
#    'ip': 2.1e-09,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.44',
#    'sigma_lov': 3.47,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.005,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.94},
#   '48': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 396000.0,
#    'ip': 1.3e-08,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.51',
#    'sigma_lov': 3.393,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.095,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.15},
#   '49': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 9470.0,
#    'ip': 2.8e-05,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.60',
#    'sigma_lov': -1.938,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.006,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -2.83},
#   '50': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 738000.0,
#    'ip': 6e-08,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.63',
#    'sigma_lov': -2.519,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.657,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -5.48},
#   '51': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 486000.0,
#    'ip': 8.5e-07,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.74',
#    'sigma_lov': 1.674,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.018,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.34},
#   '52': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 1860000.0,
#    'ip': 2.2e-09,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-24.81',
#    'sigma_lov': 3.468,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.019,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.92},
#   '53': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 2720000.0,
#    'ip': 2.1e-08,
#    'dt': <Quantity 172.49 yr>,
#    'date': '2193-09-25.67',
#    'sigma_lov': 2.585,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.124,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -5.94},
#   '54': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 919000.0,
#    'ip': 1.6e-07,
#    'dt': <Quantity 173.49 yr>,
#    'date': '2194-09-24.72',
#    'sigma_lov': -2.141,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.346,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -5.07},
#   '55': {'width': 0.0,
#    'energy': 1153.0,
#    'stretch': 14500.0,
#    'ip': 6.9e-07,
#    'dt': <Quantity 173.49 yr>,
#    'date': '2194-09-24.75',
#    'sigma_lov': 3.204,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6.01 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.008,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.43},
#   '56': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 33500.0,
#    'ip': 8.5e-07,
#    'dt': <Quantity 173.49 yr>,
#    'date': '2194-09-24.79',
#    'sigma_lov': 2.832,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.18,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.34},
#   '57': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 9550.0,
#    'ip': 1.8e-06,
#    'dt': <Quantity 173.49 yr>,
#    'date': '2194-09-24.80',
#    'sigma_lov': 2.916,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.569,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.02},
#   '58': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 2230000.0,
#    'ip': 4.2e-07,
#    'dt': <Quantity 174.49 yr>,
#    'date': '2195-09-25.27',
#    'sigma_lov': 0.96,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.294,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.65},
#   '59': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 2890000.0,
#    'ip': 1.2e-09,
#    'dt': <Quantity 175.49 yr>,
#    'date': '2196-09-23.48',
#    'sigma_lov': 3.503,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.153,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -7.2},
#   '60': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 29700.0,
#    'ip': 4.5e-08,
#    'dt': <Quantity 175.49 yr>,
#    'date': '2196-09-24.21',
#    'sigma_lov': 3.772,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.052,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.62},
#   '61': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 12000.0,
#    'ip': 6.1e-08,
#    'dt': <Quantity 175.49 yr>,
#    'date': '2196-09-24.27',
#    'sigma_lov': 3.822,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.637,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.49},
#   '62': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 47400.0,
#    'ip': 3.5e-05,
#    'dt': <Quantity 175.49 yr>,
#    'date': '2196-09-24.31',
#    'sigma_lov': -0.092,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.001,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -2.73},
#   '63': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 16800.0,
#    'ip': 9.4e-05,
#    'dt': <Quantity 175.49 yr>,
#    'date': '2196-09-24.33',
#    'sigma_lov': -0.065,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.151,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -2.3},
#   '64': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 462000.0,
#    'ip': 1.8e-09,
#    'dt': <Quantity 176.49 yr>,
#    'date': '2197-09-24.58',
#    'sigma_lov': 3.599,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.912,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -7.01},
#   '65': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 862000.0,
#    'ip': 3.1e-08,
#    'dt': <Quantity 176.49 yr>,
#    'date': '2197-09-24.80',
#    'sigma_lov': -2.883,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.008,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -5.79},
#   '66': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1780000.0,
#    'ip': 2.1e-09,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.38',
#    'sigma_lov': 3.498,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.019,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -6.96},
#   '67': {'width': 0.0,
#    'energy': 1153.0,
#    'stretch': 485000.0,
#    'ip': 5e-09,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.55',
#    'sigma_lov': 3.472,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6.01 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.001,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -6.58},
#   '68': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 2080000.0,
#    'ip': 7.8e-07,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.74',
#    'sigma_lov': -0.193,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.069,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.39},
#   '69': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 281000.0,
#    'ip': 3.3e-10,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.85',
#    'sigma_lov': -4.254,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.813,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -7.76},
#   '70': {'width': 0.0,
#    'energy': 1151.0,
#    'stretch': 895000.0,
#    'ip': 3e-07,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.88',
#    'sigma_lov': -1.924,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.99 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.003,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.81},
#   '71': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 2540000.0,
#    'ip': 1.3e-09,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.89',
#    'sigma_lov': 3.498,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.254,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -7.16},
#   '72': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 312000.0,
#    'ip': 1.5e-06,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.91',
#    'sigma_lov': -1.45,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.402,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.09},
#   '73': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 1010000.0,
#    'ip': 1.5e-07,
#    'dt': <Quantity 177.49 yr>,
#    'date': '2198-09-24.93',
#    'sigma_lov': 1.701,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.883,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -5.11},
#   '74': {'width': 0.0,
#    'energy': 1152.0,
#    'stretch': 649000.0,
#    'ip': 8.7e-07,
#    'dt': <Quantity 178.49 yr>,
#    'date': '2199-09-24.92',
#    'sigma_lov': -0.92,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 6. km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.78,
#    'v_imp': <Quantity 12.69 km / s>,
#    'ps': -4.34},
#   '75': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 953000.0,
#    'ip': 2.6e-07,
#    'dt': <Quantity 178.49 yr>,
#    'date': '2199-09-24.98',
#    'sigma_lov': -1.952,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.085,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.87},
#   '76': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 834000.0,
#    'ip': 3.5e-07,
#    'dt': <Quantity 178.49 yr>,
#    'date': '2199-09-25.11',
#    'sigma_lov': -1.813,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.24,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -4.73},
#   '77': {'width': 0.0,
#    'energy': 1150.0,
#    'stretch': 1390000.0,
#    'ip': 2.1e-09,
#    'dt': <Quantity 178.49 yr>,
#    'date': '2199-09-25.11',
#    'sigma_lov': 3.532,
#    'h': <Quantity 20.19 mag>,
#    'mass': <Quantity 6.01e+10 kg>,
#    'v_inf': <Quantity 5.98 km / s>,
#    'sigma_imp': 0.0,
#    'method': 'LOV',
#    'ts': None,
#    'diam': <Quantity 0.49 km>,
#    'dist': 0.261,
#    'v_imp': <Quantity 12.68 km / s>,
#    'ps': -6.96}},
#  'spectral_category_flag': 'B',
#  'spectral_category': 'B'}
